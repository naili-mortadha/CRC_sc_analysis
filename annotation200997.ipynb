# %%
import scanpy as sc
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scvi
import celltypist
from celltypist import models

# %%
import warnings
warnings.simplefilter("ignore", FutureWarning)
warnings.simplefilter("ignore", UserWarning)
warnings.simplefilter("ignore", RuntimeWarning)

# %%
models.get_all_models()
# Out:
# ['Pan_Fetal_Human.pkl',
#  'Human_PF_Lung.pkl',
#  'Healthy_COVID19_PBMC.pkl',
#  'Developing_Human_Organs.pkl',
#  'Mouse_Dentate_Gyrus.pkl',
#  'Cells_Lung_Airway.pkl',
#  'Cells_Fetal_Lung.pkl',
#  'Adult_Human_Skin.pkl',
#  'Adult_RhesusMacaque_Hippocampus.pkl',
#  'Adult_Human_PancreaticIslet.pkl',
#  'Fetal_Human_Pancreas.pkl',
#  'Human_Longitudinal_Hippocampus.pkl',
#  'Developing_Human_Hippocampus.pkl',
#  'Adult_Pig_Hippocampus.pkl',
#  'Mouse_Postnatal_DentateGyrus.pkl',
#  'Cells_Adult_Breast.pkl',
#  'Human_Colorectal_Cancer.pkl',
#  'Human_Placenta_Decidua.pkl',
#  'Fetal_Human_Pituitary.pkl',
#  'Adult_Human_Vascular.pkl',
#  'Fetal_Human_AdrenalGlands.pkl',
#  'Nuclei_Lung_Airway.pkl',
#  'Human_Endometrium_Atlas.pkl',
#  'Developing_Human_Brain.pkl',
#  'Fetal_Human_Retina.pkl',
#  'Human_IPF_Lung.pkl',
#  'Adult_COVID19_PBMC.pkl',
#  'Healthy_Adult_Heart.pkl',
#  'Human_Lung_Atlas.pkl',
#  'Mouse_Whole_Brain.pkl',
#  'Adult_Mouse_OlfactoryBulb.pkl',
#  'COVID19_HumanChallenge_Blood.pkl',
#  'Human_Embryonic_YolkSac.pkl',
#  'Human_Developmental_Retina.pkl',
#  'Human_AdultAged_Hippocampus.pkl',
#  'Developing_Human_Gonads.pkl',
#  'Healthy_Mouse_Liver.pkl',
#  'Adult_CynomolgusMacaque_Hippocampus.pkl',
#  'Immune_All_Low.pkl',
#  'Cells_Human_Tonsil.pkl',
#  'Adult_Human_PrefrontalCortex.pkl',
#  'Adult_Human_MTG.pkl',
#  'Mouse_Isocortex_Hippocampus.pkl',
#  'Immune_All_High.pkl',
#  'Autopsy_COVID19_Lung.pkl',
#  'Healthy_Human_Liver.pkl',
#  'Developing_Mouse_Hippocampus.pkl',
#  'Cells_Intestinal_Tract.pkl',
#  'Fetal_Human_Skin.pkl',
#  'COVID19_Immune_Landscape.pkl',
#  'Developing_Human_Thymus.pkl',
#  'Lethal_COVID19_Lung.pkl',
#  'Developing_Mouse_Brain.pkl',
#  'Adult_Mouse_Gut.pkl']

# %%
model_low = models.Model.load(model='Human_Colorectal_Cancer.pkl')

# %%
def predict_cells(adata):
    sc.pp.filter_genes(adata, min_cells = 10)
    sc.pp.normalize_total(adata, target_sum=1e4) #not recommended for typical pp
    sc.pp.log1p(adata)

    

    predictions = celltypist.annotate(adata, model=model_low, majority_voting=False)
    predictions_adata = predictions.to_adata()
    adata.obs["low_label"] = predictions_adata.obs.loc[adata.obs.index, "predicted_labels"]
    adata.obs["low_score"] = predictions_adata.obs.loc[adata.obs.index, "conf_score"]


    return adata.obs

# %%
adatas = [sc.read_h5ad('pp_adata/' + x) for x in os.listdir('pp_adata')]

# %%
len(adatas)
# Out:
# 1

# %%
predictions = [predict_cells(ad.copy()) for ad in adatas] #we pass a copy so it doesnt normalize the counts
# Out:
# 🔬 Input data has 38228 cells and 19748 genes
# 🔗 Matching reference genes in the model
# 🧬 4050 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!

# %%
predictions = pd.concat(predictions)[['low_label', 'low_score',]]

predictions
# Out:
#                                    low_label  low_score
# B_cac10_AAACCTGCACTTCGAA        CD19+CD20+ B   1.000000
# B_cac10_AAACCTGGTAATTGGA        CD4+ T cells   0.889012
# B_cac10_AAACCTGGTACGAAAT        CD4+ T cells   0.600564
# B_cac10_AAACCTGGTGAAAGAG        Intermediate   0.523409
# B_cac10_AAACCTGTCACGATGT    Pro-inflammatory   0.417229
# ...                                      ...        ...
# T_cac9_TTTGGTTCAAATACAG              Unknown   0.288446
# T_cac9_TTTGGTTCAACACGCC   Regulatory T cells   0.925800
# T_cac9_TTTGGTTCATAGACTC         CD4+ T cells   0.986861
# T_cac9_TTTGGTTCATCTATGG                  cDC   0.932307
# T_cac9_TTTGTCAGTCCAACTA         CD8+ T cells   0.967094
#
# [38228 rows x 2 columns]

# %%
adata = sc.concat(adatas)
adata
# Out:
# AnnData object with n_obs × n_vars = 38228 × 23828
#     obs: 'samples', 'condition', 'location', 'msi_status', 'bulk_prediction', 'prediction', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb'

# %%
predictions.to_csv('PREDICTIONS_200997.csv')

# %%
adata.obs = adata.obs.merge(right = predictions, left_index=True, right_index=True)

# %%
adata.obs
# Out:
#                           samples condition location msi_status  \
# B_cac10_AAACCTGCACTTCGAA  B_cac10    Normal     Left        MSS
# B_cac10_AAACCTGGTAATTGGA  B_cac10    Normal     Left        MSS
# B_cac10_AAACCTGGTACGAAAT  B_cac10    Normal     Left        MSS
# B_cac10_AAACCTGGTGAAAGAG  B_cac10    Normal     Left        MSS
# B_cac10_AAACCTGTCACGATGT  B_cac10    Normal     Left        MSS
# ...                           ...       ...      ...        ...
# T_cac9_TTTGGTTCAAATACAG    T_cac9     Tumor     Left        MSS
# T_cac9_TTTGGTTCAACACGCC    T_cac9     Tumor     Left        MSS
# T_cac9_TTTGGTTCATAGACTC    T_cac9     Tumor     Left        MSS
# T_cac9_TTTGGTTCATCTATGG    T_cac9     Tumor     Left        MSS
# T_cac9_TTTGTCAGTCCAACTA    T_cac9     Tumor     Left        MSS
#
#                          bulk_prediction prediction  n_genes  \
# B_cac10_AAACCTGCACTTCGAA             NaN        NaN      626
# B_cac10_AAACCTGGTAATTGGA             NaN        NaN      741
# B_cac10_AAACCTGGTACGAAAT             NaN        NaN      630
# B_cac10_AAACCTGGTGAAAGAG             NaN        NaN     1053
# B_cac10_AAACCTGTCACGATGT             NaN        NaN      335
# ...                                  ...        ...      ...
# T_cac9_TTTGGTTCAAATACAG             CMS2       CMS1     2136
# T_cac9_TTTGGTTCAACACGCC             CMS2       CMS4     1355
# T_cac9_TTTGGTTCATAGACTC             CMS2       CMS4     2220
# T_cac9_TTTGGTTCATCTATGG             CMS2       CMS1     1303
# T_cac9_TTTGTCAGTCCAACTA             CMS2       CMS1     1130
#
#                           n_genes_by_counts  log1p_n_genes_by_counts  \
# B_cac10_AAACCTGCACTTCGAA                626                 6.440947
# B_cac10_AAACCTGGTAATTGGA                741                 6.609349
# B_cac10_AAACCTGGTACGAAAT                630                 6.447306
# B_cac10_AAACCTGGTGAAAGAG               1053                 6.960348
# B_cac10_AAACCTGTCACGATGT                335                 5.817111
# ...                                     ...                      ...
# T_cac9_TTTGGTTCAAATACAG                2136                 7.667158
# T_cac9_TTTGGTTCAACACGCC                1355                 7.212294
# T_cac9_TTTGGTTCATAGACTC                2220                 7.705713
# T_cac9_TTTGGTTCATCTATGG                1303                 7.173192
# T_cac9_TTTGTCAGTCCAACTA                1130                 7.030857
#
#                           total_counts  log1p_total_counts  \
# B_cac10_AAACCTGCACTTCGAA        1817.0            7.505492
# B_cac10_AAACCTGGTAATTGGA        2041.0            7.621685
# B_cac10_AAACCTGGTACGAAAT        2217.0            7.704361
# B_cac10_AAACCTGGTGAAAGAG        2708.0            7.904335
# B_cac10_AAACCTGTCACGATGT         714.0            6.572283
# ...                                ...                 ...
# T_cac9_TTTGGTTCAAATACAG         5317.0            8.578853
# T_cac9_TTTGGTTCAACACGCC         3463.0            8.150179
# T_cac9_TTTGGTTCATAGACTC         7173.0            8.878219
# T_cac9_TTTGGTTCATCTATGG         3283.0            8.096817
# T_cac9_TTTGTCAGTCCAACTA         3251.0            8.087026
#
#                           pct_counts_in_top_20_genes  pct_counts_mt  \
# B_cac10_AAACCTGCACTTCGAA                   26.637314       2.146395
# B_cac10_AAACCTGGTAATTGGA                   24.595786       4.899559
# B_cac10_AAACCTGGTACGAAAT                   29.048263       6.630582
# B_cac10_AAACCTGGTGAAAGAG                   25.553914       3.618907
# B_cac10_AAACCTGTCACGATGT                   33.473389       8.123250
# ...                                              ...            ...
# T_cac9_TTTGGTTCAAATACAG                    17.359413       7.504231
# T_cac9_TTTGGTTCAACACGCC                    19.318510       4.244874
# T_cac9_TTTGGTTCATAGACTC                    19.001812       3.987174
# T_cac9_TTTGGTTCATCTATGG                    27.231191       8.010965
# T_cac9_TTTGTCAGTCCAACTA                    22.393110       2.952938
#
#                           pct_counts_ribo  pct_counts_hb           low_label  \
# B_cac10_AAACCTGCACTTCGAA        40.286186            0.0        CD19+CD20+ B
# B_cac10_AAACCTGGTAATTGGA        40.764332            0.0        CD4+ T cells
# B_cac10_AAACCTGGTACGAAAT        50.338291            0.0        CD4+ T cells
# B_cac10_AAACCTGGTGAAAGAG        27.437222            0.0        Intermediate
# B_cac10_AAACCTGTCACGATGT        38.935574            0.0    Pro-inflammatory
# ...                                   ...            ...                 ...
# T_cac9_TTTGGTTCAAATACAG         13.673123            0.0             Unknown
# T_cac9_TTTGGTTCAACACGCC         24.631823            0.0  Regulatory T cells
# T_cac9_TTTGGTTCATAGACTC         27.798689            0.0        CD4+ T cells
# T_cac9_TTTGGTTCATCTATGG         23.484617            0.0                 cDC
# T_cac9_TTTGTCAGTCCAACTA         24.423256            0.0        CD8+ T cells
#
#                           low_score
# B_cac10_AAACCTGCACTTCGAA   1.000000
# B_cac10_AAACCTGGTAATTGGA   0.889012
# B_cac10_AAACCTGGTACGAAAT   0.600564
# B_cac10_AAACCTGGTGAAAGAG   0.523409
# B_cac10_AAACCTGTCACGATGT   0.417229
# ...                             ...
# T_cac9_TTTGGTTCAAATACAG    0.288446
# T_cac9_TTTGGTTCAACACGCC    0.925800
# T_cac9_TTTGGTTCATAGACTC    0.986861
# T_cac9_TTTGGTTCATCTATGG    0.932307
# T_cac9_TTTGTCAGTCCAACTA    0.967094
#
# [38228 rows x 17 columns]

# %%
adata.write_h5ad('200997_annotated.h5ad')
